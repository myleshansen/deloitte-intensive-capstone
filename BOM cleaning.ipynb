# %%
# import data

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('bom.movie_gross.csv.gz')

# %%
# drop missing rows
foreign_dropped = df[~df['foreign_gross'].isnull()]['foreign_gross']

# %%
# check info to see data types, column values, and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# drop null values
df_1 = df.dropna(how='any',axis=0)

# %%
# check info to see if null values were dropped successfully
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2007 entries, 0 to 3353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2007 non-null   object
#  1   studio          2007 non-null   object
#  2   domestic_gross  2007 non-null   float64
#  3   foreign_gross   2007 non-null   object
#  4   year            2007 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 94.1+ KB

# %%
# practice hist, curious to see layout of data within domestic gross value
df_1['domestic_gross'].hist()
# Out:
# <AxesSubplot:>

# %%
# convert foreign gross to a string
df_1['foreign_gross'].astype('str')
# Out:
# 0       652000000
# 1       691300000
# 2       664300000
# 3       535700000
# 4       513900000
#           ...
# 3275      1500000
# 3286       229000
# 3309       256000
# 3342         5200
# 3353        30000
# Name: foreign_gross, Length: 2007, dtype: object

# %%
# remove commas from foreign gross in order to convert it to an integer
df_1['foreign_gross']=df_1['foreign_gross'].str.replace(',','')
# Out:
# <ipython-input-9-819dcdefaca7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['foreign_gross']=df_1['foreign_gross'].str.replace(',','')

# %%
# convert foreign gross to an integer
df_1['foreign_gross'] = df_1['foreign_gross'].astype(float)
# Out:
# <ipython-input-10-018c5d81f718>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['foreign_gross'] = df_1['foreign_gross'].astype(float)

# %%
# check to see if foreign gross was successfully converted to float
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2007 entries, 0 to 3353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2007 non-null   object
#  1   studio          2007 non-null   object
#  2   domestic_gross  2007 non-null   float64
#  3   foreign_gross   2007 non-null   float64
#  4   year            2007 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 94.1+ KB

# %%
# chart foreign gross compared to domestic gross
df_1.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year
# 0    652000000.0  2010
# 1    691300000.0  2010
# 2    664300000.0  2010
# 3    535700000.0  2010
# 4    513900000.0  2010

# %%
# Sort by top movies domestic_gross
dfSort = df_1.sort_values(by='domestic_gross', ascending=False)
dfSort.head(50)
# Out:
#                                             title   studio  domestic_gross  \
# 1872                 Star Wars: The Force Awakens       BV     936700000.0
# 3080                                Black Panther       BV     700100000.0
# 3079                       Avengers: Infinity War       BV     678800000.0
# 1873                               Jurassic World     Uni.     652300000.0
# 727                         Marvel's The Avengers       BV     623400000.0
# 2758                     Star Wars: The Last Jedi       BV     620200000.0
# 3082                                Incredibles 2       BV     608600000.0
# 2323                 Rogue One: A Star Wars Story       BV     532200000.0
# 2759                  Beauty and the Beast (2017)       BV     504000000.0
# 2324                                 Finding Dory       BV     486300000.0
# 1875                      Avengers: Age of Ultron       BV     459000000.0
# 729                         The Dark Knight Rises       WB     448100000.0
# 1131              The Hunger Games: Catching Fire      LGF     424700000.0
# 3081               Jurassic World: Fallen Kingdom     Uni.     417700000.0
# 0                                     Toy Story 3       BV     415000000.0
# 2767                                 Wonder Woman       WB     412600000.0
# 1128                                   Iron Man 3       BV     409000000.0
# 2322                   Captain America: Civil War       BV     408100000.0
# 735                              The Hunger Games      LGF     408000000.0
# 2762               Jumanji: Welcome to the Jungle     Sony     404500000.0
# 1127                                       Frozen       BV     400700000.0
# 2765               Guardians of the Galaxy Vol. 2       BV     389800000.0
# 328   Harry Potter and the Deathly Hallows Part 2       WB     381000000.0
# 2327                      The Secret Life of Pets     Uni.     368400000.0
# 1129                              Despicable Me 2     Uni.     368100000.0
# 2326                       The Jungle Book (2016)       BV     364000000.0
# 2330                                     Deadpool      Fox     363100000.0
# 1878                                   Inside Out       BV     356500000.0
# 1874                                    Furious 7     Uni.     353000000.0
# 329                Transformers: Dark of the Moon     P/DW     352400000.0
# 1489                              American Sniper       WB     350100000.0
# 2325                                     Zootopia       BV     341300000.0
# 1481        The Hunger Games: Mockingjay - Part 1      LGF     337100000.0
# 1876                                      Minions     Uni.     336000000.0
# 3083                                      Aquaman       WB     335100000.0
# 2763                       Spider-Man: Homecoming     Sony     334200000.0
# 1                      Alice in Wonderland (2010)       BV     334200000.0
# 1479                      Guardians of the Galaxy       BV     333200000.0
# 2328           Batman v Superman: Dawn of Justice       WB     330400000.0
# 2770                                           It  WB (NL)     327500000.0
# 2331                                Suicide Squad       WB     325100000.0
# 3087                                   Deadpool 2      Fox     318500000.0
# 2766                               Thor: Ragnarok       BV     315100000.0
# 6                                      Iron Man 2     Par.     312400000.0
# 728                                       Skyfall     Sony     304400000.0
# 730             The Hobbit: An Unexpected Journey  WB (NL)     303000000.0
# 5                      The Twilight Saga: Eclipse     Sum.     300500000.0
# 2     Harry Potter and the Deathly Hallows Part 1       WB     296000000.0
# 3                                       Inception       WB     292600000.0
# 732       The Twilight Saga: Breaking Dawn Part 2     LG/S     292300000.0
#
#       foreign_gross  year
# 1872         1131.6  2015
# 3080    646900000.0  2018
# 3079         1369.5  2018
# 1873         1019.4  2015
# 727     895500000.0  2012
# 2758    712400000.0  2017
# 3082    634200000.0  2018
# 2323    523900000.0  2016
# 2759    759500000.0  2017
# 2324    542300000.0  2016
# 1875    946400000.0  2015
# 729     636800000.0  2012
# 1131    440300000.0  2013
# 3081    891800000.0  2018
# 0       652000000.0  2010
# 2767    409300000.0  2017
# 1128    805800000.0  2013
# 2322    745200000.0  2016
# 735     286400000.0  2012
# 2762    557600000.0  2017
# 1127    875700000.0  2013
# 2765    473900000.0  2017
# 328     960500000.0  2011
# 2327    507100000.0  2016
# 1129    602700000.0  2013
# 2326    602500000.0  2016
# 2330    420000000.0  2016
# 1878    501100000.0  2015
# 1874         1163.0  2015
# 329     771400000.0  2011
# 1489    197300000.0  2014
# 2325    682500000.0  2016
# 1481    418200000.0  2014
# 1876    823400000.0  2015
# 3083    812700000.0  2018
# 2763    546000000.0  2017
# 1       691300000.0  2010
# 1479    440200000.0  2014
# 2328    543300000.0  2016
# 2770    372900000.0  2017
# 2331    421700000.0  2016
# 3087    460500000.0  2018
# 2766    538900000.0  2017
# 6       311500000.0  2010
# 728     804200000.0  2012
# 730     718100000.0  2012
# 5       398000000.0  2010
# 2       664300000.0  2010
# 3       535700000.0  2010
# 732     537400000.0  2012
